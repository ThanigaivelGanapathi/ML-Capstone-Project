# %%
import numpy as np
import pandas as pd
from sklearn.utils import shuffle

# %%
dataset = pd.read_csv("Loan_default.csv")

# %%
dataset
# Out:
#             LoanID   Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0       I38PQUQS96  56.0   85994       50587          520              80
# 1       HPSK72WA7R  69.0   50432      124440          458              15
# 2       C1OZ6DPJ8Y  46.0   84208      129188          451              26
# 3       V2KKSFM3UN  32.0   31713       44799          743               0
# 4       EY08JDHTZP  60.0   20437        9139          633               8
# ...            ...   ...     ...         ...          ...             ...
# 255342  8C6S86ESGC  19.0   37979      210682          541             109
# 255343  98R4KDHNND  32.0   51953      189899          511              14
# 255344  XQK1UUUNGP  56.0   84820      208294          597              70
# 255345  JAO28CPL4H  42.0   85109       60575          809              40
# 255346  ZTH91CGL0B  62.0   22418       18481          636             113
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# ...

# %%
new_data = dataset.copy()

# %%
new_data
# Out:
#             LoanID   Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0       I38PQUQS96  56.0   85994       50587          520              80
# 1       HPSK72WA7R  69.0   50432      124440          458              15
# 2       C1OZ6DPJ8Y  46.0   84208      129188          451              26
# 3       V2KKSFM3UN  32.0   31713       44799          743               0
# 4       EY08JDHTZP  60.0   20437        9139          633               8
# ...            ...   ...     ...         ...          ...             ...
# 255342  8C6S86ESGC  19.0   37979      210682          541             109
# 255343  98R4KDHNND  32.0   51953      189899          511              14
# 255344  XQK1UUUNGP  56.0   84820      208294          597              70
# 255345  JAO28CPL4H  42.0   85109       60575          809              40
# 255346  ZTH91CGL0B  62.0   22418       18481          636             113
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# ...

# %%
new_data.drop(["LoanID"],axis = 1,inplace = True)

# %%
new_data
# Out:
#          Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0       56.0   85994       50587          520              80               4
# 1       69.0   50432      124440          458              15               1
# 2       46.0   84208      129188          451              26               3
# 3       32.0   31713       44799          743               0               3
# 4       60.0   20437        9139          633               8               4
# ...      ...     ...         ...          ...             ...             ...
# 255342  19.0   37979      210682          541             109               4
# 255343  32.0   51953      189899          511              14               2
# 255344  56.0   84820      208294          597              70               3
# 255345  42.0   85109       60575          809              40               1
# 255346  62.0   22418       18481          636             113               2
#
# ...

# %%
new_data.describe()
# Out:
#                  Age         Income     LoanAmount    CreditScore  \
# count  255344.000000  255347.000000  255347.000000  255347.000000
# mean       43.498473   82499.304597  127578.865512     574.264346
# std        14.990245   38963.013729   70840.706142     158.903867
# min        18.000000   15000.000000    5000.000000     300.000000
# 25%        31.000000   48825.500000   66156.000000     437.000000
# 50%        43.000000   82466.000000  127556.000000     574.000000
# 75%        56.000000  116219.000000  188985.000000     712.000000
# max        69.000000  149999.000000  249999.000000     849.000000
#
#        MonthsEmployed  NumCreditLines   InterestRate       LoanTerm  \
# count   255347.000000   255347.000000  255347.000000  255347.000000
# mean        59.541976        2.501036      13.492773      36.025894
# std         34.643376        1.117018       6.636443      16.969330
# min          0.000000        1.000000       2.000000      12.000000
# ...

# %%
new_data["Default"].value_counts()
# Out:
# Default
# 0    225694
# 1     29653
# Name: count, dtype: int64

# %%
yes_data = new_data[new_data["Default"] == 1]
no_data  = new_data[new_data["Default"] == 0]

# %%
yes_data
# Out:
#          Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 2       46.0   84208      129188          451              26               3
# 5       25.0   90298       90448          720              18               2
# 8       36.0   42053       92357          827              83               1
# 11      28.0  149227      139759          375              56               3
# 18      19.0   40718       78515          319             119               2
# ...      ...     ...         ...          ...             ...             ...
# 255310  65.0  111206      112192          315               3               3
# 255324  50.0   34641      108855          347              17               4
# 255333  22.0   45575       43355          545              99               1
# 255341  40.0  129890      116119          701              38               3
# 255343  32.0   51953      189899          511              14               2
#
# ...

# %%
min_size = min(len(yes_data), len(no_data))
min_size
# Out:
# 29653

# %%
min_yes_data = yes_data.sample(min_size,random_state = 42)
min_no_data  = no_data.sample(min_size,random_state = 42)

# %%
min_no_data
# Out:
#          Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 191649  58.0  108264       61367          453              72               3
# 243439  42.0   71611       31938          663              91               2
# 175764  31.0   30753      216354          740              38               2
# 185368  40.0  130612       53234          539              18               3
# 68741   68.0   70154      243294          603              57               2
# ...      ...     ...         ...          ...             ...             ...
# 141018  50.0  129003      209873          782              88               2
# 25164   66.0   83074      101042          590               4               1
# 23196   68.0   16725       32990          640              67               3
# 117209  33.0   71765      213702          569              38               3
# 191726  23.0  116878      154673          394              62               4
#
# ...

# %%
balanced_data = pd.concat([min_yes_data,min_no_data])

# %%
balanced_data
# Out:
#          Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 220566  21.0  128833       96957          317              83               2
# 210651  23.0   17721      218809          459              10               1
# 230621  40.0   95675      237929          651              64               3
# 74658   47.0   29796      235097          650             100               1
# 224696  38.0   57457      149730          480             106               2
# ...      ...     ...         ...          ...             ...             ...
# 141018  50.0  129003      209873          782              88               2
# 25164   66.0   83074      101042          590               4               1
# 23196   68.0   16725       32990          640              67               3
# 117209  33.0   71765      213702          569              38               3
# 191726  23.0  116878      154673          394              62               4
#
# ...

# %%
balanced_data=  shuffle(balanced_data, random_state=42)

# %%
balanced_data
# Out:
#          Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 98430   41.0   31683      216645          683              61               3
# 146589  26.0   93197      205268          839             111               4
# 198457  24.0   98965       20343          353              75               4
# 94450   32.0   47089       82670          803              74               1
# 165850  60.0   55253       84223          418              26               3
# ...      ...     ...         ...          ...             ...             ...
# 21217   19.0  137150      132044          401              49               4
# 125452  67.0  118791      170329          733              75               2
# 6411    27.0  133821       25974          602              54               3
# 45993   24.0  142223      144482          649              55               4
# 93031   23.0  135709      137238          805              14               4
#
# ...

# %%
reduced_data = balanced_data.sample(n=1000,random_state = 42)

# %%
reduced_data
# Out:
#          Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 233937  22.0  111976      172949          457              22               1
# 229426  20.0   91246      233720          690              55               3
# 214204  18.0  116886      172974          591              10               3
# 91339   33.0   50824      134107          443              70               2
# 202096  53.0  115120      240301          459              40               2
# ...      ...     ...         ...          ...             ...             ...
# 138128  30.0  104348       37253          649              73               3
# 32935   48.0   44714       21976          671              80               3
# 88117   43.0  149140      116540          675              43               1
# 194560  57.0   78284       10346          702              89               4
# 104756  62.0  106491       56860          309             110               2
#
# ...

# %%
reduced_data["Default"].value_counts()
# Out:
# Default
# 1    506
# 0    494
# Name: count, dtype: int64

# %%
balanced_data["Default"].value_counts()
# Out:
# Default
# 1    29653
# 0    29653
# Name: count, dtype: int64

# %%
final_yes = balanced_data[balanced_data['Default'] == 1].sample(n=500, random_state=42)
final_no = balanced_data[balanced_data['Default'] == 0].sample(n=500, random_state=42)

# %%
new_reduced_data = pd.concat([final_yes, final_no])

# %%
new_reduced_data = shuffle(new_reduced_data, random_state = 42)

# %%
new_reduced_data["Default"].value_counts()
# Out:
# Default
# 0    500
# 1    500
# Name: count, dtype: int64

# %%
new_reduced_data
# Out:
#          Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 176589  48.0   90754        5902          462              91               2
# 244769  24.0   59193       90049          309              73               1
# 28742   55.0   77343      204141          423              19               2
# 37291   18.0   25087       15645          474              23               4
# 152853  31.0   33215      235022          771              67               3
# ...      ...     ...         ...          ...             ...             ...
# 25028   59.0  127901       46482          424              44               4
# 157822  54.0  139677      138362          780              27               3
# 66295   42.0   53038       62256          763             116               3
# 14592   43.0  137420      116698          424              21               4
# 213377  48.0   33362      205046          750               2               2
#
# ...

# %%
new_reduced_data.to_csv("Balanced_Dataset.csv",index = False)
